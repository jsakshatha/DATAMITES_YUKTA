# %%
import numpy as np
import pickle
import pandas as pd
from preprocess1 import *  # this is for loading the .py file which contains all the libraries and the custom functions.
from imblearn.over_sampling import SMOTE
# Out:
# C:\Users\snehr\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  418 non-null    int64
#  1   Pclass    418 non-null    int64
#  2   Sex       418 non-null    object
#  3   Age       418 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Fare      418 non-null    float64
#  7   Embarked  418 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 26.2+ KB

# %% [markdown]
# #  Load the pickle file :

# %%
file=open("demo.pkl","rb")

# %% [markdown]
# # Load the preprocessor :

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
pre
# Out:
# ColumnTransformer(transformers=[('OHE_columns', OneHotEncoder(), ['Sex']),
#                                 ('standard_scaler', StandardScaler(),
#                                  ['Age', 'Fare']),
#                                 ('custom',
#                                  FunctionTransformer(func=<function divide_by_100 at 0x000001FE095077F0>),
#                                  ['Age']),
#                                 ('ordinal_Sib',
#                                  OrdinalEncoder(categories=[['0', '1', '2', '3',
#                                                              '4', '5', '8']]),
#                                  ['SibSp']),
#                                 ('Label_encoder', ModifiedLabelEncoder(),
#                                  ['Embarked'])])

# %% [markdown]
# ## This is the preprocessor that was defined in the previous file.

# %% [markdown]
# - You can load the preprocessor pipeline  anywhere using the above code for further processsing and for model evaluation.

# %% [markdown]
# ### What are the further processing steps:
#
# - You need to further check for the null values.
# - Correlation between the target columns and the other columns.
# - Check for outliers too and if having remove them.
# - Scaling the data if needed.
# - use transformation if the columns were skewed in distribution.
# - splitting the data in train and test.
# - Model Creation.
# - Model evaluation.
# - Hyperparameter Tune the model for the better results.

# %% [markdown]
# # Imputing null values :

# %%
df=df.drop(['Ticket','PassengerId','Name','Cabin'], axis=1)

# %%
df.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
df.loc[df['Age'].isnull(),'Age']=df['Age'].median()

# %%
df.loc[df['Fare'].isnull(),'Fare']=50

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Transforming the data :

# %%
processed_data=pre.fit_transform(df)
# Out:
# C:\Users\snehr\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
processed_data
# Out:
# array([[ 0.        ,  1.        ,  0.38623105, ...,  0.345     ,
#          0.        ,  1.        ],
#        [ 1.        ,  0.        ,  1.37137004, ...,  0.47      ,
#          1.        ,  2.        ],
#        [ 0.        ,  1.        ,  2.55353683, ...,  0.62      ,
#          0.        ,  1.        ],
#        ...,
#        [ 0.        ,  1.        ,  0.70147553, ...,  0.385     ,
#          0.        ,  2.        ],
#        [ 0.        ,  1.        , -0.20485235, ...,  0.27      ,
#          0.        ,  2.        ],
#        [ 0.        ,  1.        , -0.20485235, ...,  0.27      ,
#          1.        ,  0.        ]])

# %% [markdown]
# ## Now the dataset is preprocessed and can be used by a model.

# %% [markdown]
#                                           ** HAPPY LEARNING **
